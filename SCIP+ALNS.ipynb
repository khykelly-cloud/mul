# %% [markdown]
# <a href="https://colab.research.google.com/github/khykelly-cloud/mul/blob/main/SCIP%2BALNS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# Colab 버전 코드 (SCIP + HEAVY ALNS)
# - MILP: PySCIPOpt (SCIP)  → DC 개설/배정 (Facility Location)
# - VRP: HEAVY ALNS 기반 CVRP (트럭 용량 160, depot 복귀)
# - 케이스 A/B/C/D 4개 한 번에 실행
#   * B: λ 자동 탐색
#   * C: min_cust 자동 탐색
#   * D: (λ, min_cust) 그리드 서치
# =========================================================

# !pip install pyscipopt --quiet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import copy
import math
from pyscipopt import Model, quicksum

# ---------------------------------------------
# 0) 데이터 로드
# ---------------------------------------------
customer = pd.read_csv("/content/Customer.csv").reset_index().rename(columns={"index": "Customer_ID"})
dc       = pd.read_csv("/content/DistributionCenter.csv").reset_index().rename(columns={"index": "DC_ID"})
truck    = pd.read_csv("/content/Truck.csv")

C = len(customer)   # 고객 수 (예: 50)
D = len(dc)         # DC 수   (예: 5)

TRUCK_CAPACITY = int(truck["CAPACITY"].iloc[0])   # 예: 160
open_cost_j    = dc["COST"].values               # DC 개설비용
dc_capacity_j  = dc["CAPACITY"].values           # DC 보관용량

demand        = customer["DEMAND"].values
total_demand  = demand.sum()

cust_coords = [(customer.loc[i, "X"], customer.loc[i, "Y"]) for i in range(C)]
dc_coords   = [(dc.loc[j, "X"],       dc.loc[j, "Y"])       for j in range(D)]

# ---------------------------------------------
# 1) 유틸 (거리)
# ---------------------------------------------
def euclid(p1, p2):
    return np.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

# ---------------------------------------------
# 2) ALNS용 CVRP 유틸 함수들 (HEAVY 버전)
# ---------------------------------------------
def compute_route_cost(route, dist_matrix):
    """ route: [0, i1, i2, ..., 0] """
    c = 0.0
    for k in range(len(route) - 1):
        c += dist_matrix[route[k]][route[k+1]]
    return c

def compute_total_cost(routes, dist_matrix):
    return sum(compute_route_cost(r, dist_matrix) for r in routes)

def compute_route_demand(route, demands):
    """ route 안 고객 수요 합 (depot=0은 제외) """
    return sum(demands[node] for node in route if node != 0)

def initial_solution_greedy(demands, dist_matrix, vehicle_capacity, seed=0):
    """
    단순 greedy CVRP 초기해:
    - 고객 순서를 랜덤으로 섞고,
    - 남아 있는 용량이 되는 라우트에 차례대로 넣음
    - 안 들어가면 새 route 생성
    """
    random.seed(seed)
    np.random.seed(seed)

    n = len(demands)  # 0 포함
    customer_ids = list(range(1, n))
    random.shuffle(customer_ids)

    total_demand = sum(demands[1:])
    num_vehicles = max(1, int(np.ceil(total_demand / vehicle_capacity)))

    routes = []
    remaining_cap = []

    for _ in range(num_vehicles):
        routes.append([0, 0])  # depot → depot
        remaining_cap.append(vehicle_capacity)

    for cust in customer_ids:
        d = demands[cust]
        inserted = False
        for r_idx in range(len(routes)):
            if remaining_cap[r_idx] >= d:
                routes[r_idx].insert(-1, cust)
                remaining_cap[r_idx] -= d
                inserted = True
                break
        if not inserted:
            routes.append([0, cust, 0])
            remaining_cap.append(vehicle_capacity - d)

    clean_routes = []
    for r in routes:
        if len(r) > 2:
            clean_routes.append(r)
    if not clean_routes:
        clean_routes = [[0, 0]]

    return clean_routes

# ---------------------------------------------
# 3) ALNS: Destroy 연산자들 (HEAVY)
# ---------------------------------------------
def destroy_random(routes, num_remove, demands=None, dist_matrix=None):
    """
    무작위 고객 제거
    """
    new_routes = copy.deepcopy(routes)
    removed = []

    # 모든 고객 리스트
    all_customers = []
    for r in new_routes:
        for node in r:
            if node != 0:
                all_customers.append(node)

    if not all_customers:
        return new_routes, removed

    random.shuffle(all_customers)
    to_remove = all_customers[:num_remove]

    for cust in to_remove:
        for r in new_routes:
            if cust in r:
                r.remove(cust)
                removed.append(cust)
                break

    # 빈 라우트 제거
    cleaned_routes = []
    for r in new_routes:
        if len(r) > 2:
            cleaned_routes.append(r)
    if not cleaned_routes:
        cleaned_routes = [[0, 0]]

    return cleaned_routes, removed


def destroy_worst(routes, num_remove, demands, dist_matrix):
    """
    '비용에 많이 기여하는' 고객 위주 제거:
    각 고객의 marginal cost를 대략 계산해서 큰 순서대로 제거
    """
    new_routes = copy.deepcopy(routes)
    customer_marginal = []

    for r_idx, r in enumerate(new_routes):
        if len(r) <= 2:
            continue
        for p in range(1, len(r)-1):
            c = r[p]
            prev_node = r[p-1]
            next_node = r[p+1]
            delta = dist_matrix[prev_node][c] + dist_matrix[c][next_node] - dist_matrix[prev_node][next_node]
            customer_marginal.append((c, r_idx, p, delta))

    if not customer_marginal:
        return destroy_random(routes, num_remove, demands, dist_matrix)

    customer_marginal.sort(key=lambda x: x[3], reverse=True)  # delta 큰 순

    removed = []
    used = set()
    for info in customer_marginal:
        c, r_idx, p, delta = info
        if c in used:
            continue
        used.add(c)
        removed.append(c)
        if len(removed) >= num_remove:
            break

    for c in removed:
        for r in new_routes:
            if c in r:
                r.remove(c)
                break

    cleaned_routes = []
    for r in new_routes:
        if len(r) > 2:
            cleaned_routes.append(r)
    if not cleaned_routes:
        cleaned_routes = [[0, 0]]

    return cleaned_routes, removed


def destroy_route(routes, num_remove, demands=None, dist_matrix=None):
    """
    통째로 라우트 하나(또는 일부)를 날리는 destroy
    """
    new_routes = copy.deepcopy(routes)
    non_empty = [idx for idx, r in enumerate(new_routes) if len(r) > 2]
    if not non_empty:
        return destroy_random(routes, num_remove, demands, dist_matrix)

    r_idx = random.choice(non_empty)
    r = new_routes[r_idx]

    customers_in_route = [node for node in r if node != 0]
    random.shuffle(customers_in_route)

    removed = []
    for c in customers_in_route:
        if len(removed) >= num_remove:
            break
        r.remove(c)
        removed.append(c)

    cleaned_routes = []
    for rt in new_routes:
        if len(rt) > 2:
            cleaned_routes.append(rt)
    if not cleaned_routes:
        cleaned_routes = [[0, 0]]

    return cleaned_routes, removed


def destroy_shaw(routes, num_remove, demands, dist_matrix):
    """
    Shaw destroy (유사 고객 묶어서 제거하는 연산자)
    - 거리 기준으로 가까운 고객들을 우선적으로 같이 제거
    """
    new_routes = copy.deepcopy(routes)

    # 모든 고객 모으기
    all_customers = []
    for r in new_routes:
        for node in r:
            if node != 0:
                all_customers.append(node)

    if not all_customers:
        return new_routes, []

    removed = []

    # seed customer 하나 선택
    seed = random.choice(all_customers)
    removed.append(seed)

    # seed 제거
    for r in new_routes:
        if seed in r:
            r.remove(seed)
            break

    # 남은 고객 중 seed와 가까운 애들 위주로 선택
    remaining = [c for c in all_customers if c != seed]

    while len(removed) < num_remove and remaining:
        last = removed[-1]
        # last와의 거리가 가장 가까운 customer 선택
        nearest = min(remaining, key=lambda c: dist_matrix[last][c])
        remaining.remove(nearest)
        removed.append(nearest)
        for r in new_routes:
            if nearest in r:
                r.remove(nearest)
                break

    cleaned_routes = []
    for r in new_routes:
        if len(r) > 2:
            cleaned_routes.append(r)
    if not cleaned_routes:
        cleaned_routes = [[0, 0]]

    return cleaned_routes, removed


# Destroy 연산자 리스트 (4개)
DESTROY_OPERATORS = [
    destroy_random,
    destroy_worst,
    destroy_route,
    destroy_shaw,
]

# ---------------------------------------------
# 4) ALNS: Repair 연산자들 + 2-opt Local Search
# ---------------------------------------------
def insert_feasible_min_cost(routes, cust, demands, dist_matrix, vehicle_capacity):
    """
    한 고객 cust를 capacity 안에서 최소 증가 비용 위치에 삽입
    - 기존 route들 중 feasible한 곳에 넣고
    - feasible한 곳이 하나도 없으면 새 route 생성
    """
    best_cost = float("inf")
    best_r_idx = None
    best_pos = None

    for r_idx, r in enumerate(routes):
        for pos in range(1, len(r)):  # depot 뒤~마지막 노드 앞
            new_route = r[:pos] + [cust] + r[pos:]
            if compute_route_demand(new_route, demands) > vehicle_capacity + 1e-9:
                continue
            delta = compute_route_cost(new_route, dist_matrix) - compute_route_cost(r, dist_matrix)
            if delta < best_cost:
                best_cost = delta
                best_r_idx = r_idx
                best_pos = pos

    if best_r_idx is not None:
        routes[best_r_idx] = routes[best_r_idx][:best_pos] + [cust] + routes[best_r_idx][best_pos:]
        return routes

    # 어디에도 못 넣으면 새 route 생성
    routes.append([0, cust, 0])
    return routes


def repair_greedy(routes, removed, demands, dist_matrix, vehicle_capacity):
    """
    Greedy repair:
    - removed 고객들을 아무 순서대로 순차 삽입
    """
    new_routes = copy.deepcopy(routes)
    for cust in removed:
        new_routes = insert_feasible_min_cost(new_routes, cust, demands, dist_matrix, vehicle_capacity)
    return new_routes


def repair_regret2(routes, removed, demands, dist_matrix, vehicle_capacity):
    """
    Regret-2 기반 repair:
    - 각 고객에 대해 1, 2번째 best 삽입 비용 계산
    - (2번째 - 1번째) regret 값이 큰 고객부터 삽입
    """
    new_routes = copy.deepcopy(routes)
    remaining = set(removed)

    while remaining:
        best_c = None
        best_regret = -1
        best_position_info = None

        for cust in remaining:
            best1 = float("inf")
            best2 = float("inf")
            best1_info = None

            for r_idx, r in enumerate(new_routes):
                for pos in range(1, len(r)):
                    new_route = r[:pos] + [cust] + r[pos:]
                    if compute_route_demand(new_route, demands) > vehicle_capacity + 1e-9:
                        continue
                    delta = compute_route_cost(new_route, dist_matrix) - compute_route_cost(r, dist_matrix)
                    if delta < best1:
                        best2 = best1
                        best1 = delta
                        best1_info = (r_idx, pos)
                    elif delta < best2:
                        best2 = delta

            if best1_info is None:
                # 새 route 만들어서 넣는 delta는 단순 0→cust→0 비용
                delta_new_route = compute_route_cost([0, cust, 0], dist_matrix)
                best1 = delta_new_route
                best2 = delta_new_route
                best1_info = ("new", None)

            regret = best2 - best1
            if regret > best_regret:
                best_regret = regret
                best_c = cust
                best_position_info = (best1_info, best1)

        (r_info, pos), _ = best_position_info
        if r_info == "new":
            new_routes.append([0, best_c, 0])
        else:
            r_idx = r_info
            route = new_routes[r_idx]
            new_routes[r_idx] = route[:pos] + [best_c] + route[pos:]

        remaining.remove(best_c)

    return new_routes

# Repair 연산자 리스트
REPAIR_OPERATORS = [
    repair_greedy,
    repair_regret2,
]

# ---------------------------------------------
# 2-opt Local Search (intra-route)
# ---------------------------------------------
def two_opt_route(route, dist_matrix):
    """
    한 route에 대해 2-opt 로컬 서치 (depot 0 포함)
    """
    best_route = route
    best_cost = compute_route_cost(route, dist_matrix)
    improved = True

    while improved:
        improved = False
        # 1 ~ len-2 사이에서 스왑 (양 끝의 depot(0)은 고정)
        for i in range(1, len(best_route) - 2):
            for j in range(i + 1, len(best_route) - 1):
                if j - i == 1:
                    continue
                new_route = best_route[:i] + best_route[i:j][::-1] + best_route[j:]
                new_cost = compute_route_cost(new_route, dist_matrix)
                if new_cost + 1e-9 < best_cost:
                    best_route = new_route
                    best_cost = new_cost
                    improved = True
        # 개선 없으면 종료
    return best_route


def local_search_2opt(routes, dist_matrix):
    """
    모든 route에 대해 2-opt 한 번씩 적용
    """
    new_routes = []
    for r in routes:
        if len(r) > 3:
            new_routes.append(two_opt_route(r, dist_matrix))
        else:
            new_routes.append(r)
    return new_routes

# ---------------------------------------------
# 5) ALNS 메인 루프 (HEAVY CVRP)
# ---------------------------------------------
def alns_cvrp(demands, dist_matrix, vehicle_capacity,
              max_iter=2000,
              min_remove_frac=0.2,
              max_remove_frac=0.5,
              reaction_factor=0.2,
              start_temp=1.0,
              end_temp=0.01,
              inner_loops=5,
              seed=0,
              verbose=False):
    """
    HEAVY ALNS for CVRP (단일 depot)
    - representation: routes = [ [0, ..., 0], ... ]
    - demands[0] = 0
    """

    random.seed(seed)
    np.random.seed(seed)

    # 초기해
    current_routes = initial_solution_greedy(demands, dist_matrix, vehicle_capacity, seed=seed)
    current_routes = local_search_2opt(current_routes, dist_matrix)  # 2-opt로 한 번 정리
    current_cost   = compute_total_cost(current_routes, dist_matrix)

    best_routes = copy.deepcopy(current_routes)
    best_cost   = current_cost

    num_customers = len(demands) - 1

    # destroy / repair operator별 weight / score 초기화
    nD = len(DESTROY_OPERATORS)
    nR = len(REPAIR_OPERATORS)

    destroy_weights = [1.0] * nD
    repair_weights  = [1.0] * nR

    destroy_scores = [0.0] * nD
    repair_scores  = [0.0] * nR

    def select_index(weights):
        s = sum(weights)
        r = random.random() * s
        acc = 0.0
        for i, w in enumerate(weights):
            acc += w
            if r <= acc:
                return i
        return len(weights) - 1

    def temperature(iteration):
        # 선형 cool-down
        return start_temp + (end_temp - start_temp) * (iteration / max_iter)

    if verbose:
        print(f"[ALNS-HEAVY] Initial cost = {best_cost:.2f}, routes = {best_routes}")

    for it in range(1, max_iter+1):
        T = temperature(it)

        # --- 이 iteration에서의 best candidate (inner_loops 중) ---
        iter_best_routes = None
        iter_best_cost   = float("inf")
        iter_best_d_idx  = None
        iter_best_r_idx  = None
        iter_best_improvement = False

        # inner_loops 번 destroy+repair 시도하고 그 중 제일 좋은 후보만 채택 대상으로 사용
        for _ in range(inner_loops):
            # 1) 연산자 선택
            d_idx = select_index(destroy_weights)
            r_idx = select_index(repair_weights)

            destroy_op = DESTROY_OPERATORS[d_idx]
            repair_op  = REPAIR_OPERATORS[r_idx]

            # 동적으로 remove_fraction 결정
            remove_fraction = np.random.uniform(min_remove_frac, max_remove_frac)
            num_remove = max(1, int(num_customers * remove_fraction))

            # 2) Destroy + Repair
            destroyed_routes, removed = destroy_op(current_routes, num_remove, demands, dist_matrix)
            candidate_routes = repair_op(destroyed_routes, removed, demands, dist_matrix, vehicle_capacity)

            # 2-opt local search
            candidate_routes = local_search_2opt(candidate_routes, dist_matrix)
            candidate_cost   = compute_total_cost(candidate_routes, dist_matrix)

            if candidate_cost < iter_best_cost:
                iter_best_cost  = candidate_cost
                iter_best_routes = candidate_routes
                iter_best_d_idx  = d_idx
                iter_best_r_idx  = r_idx
                iter_best_improvement = (candidate_cost < current_cost - 1e-9)

        # --- SA 기반 수용 여부 결정 ---
        if iter_best_routes is None:
            # inner_loops 동안 feasible한 해를 못 만든 경우
            continue

        delta = iter_best_cost - current_cost
        accept = False
        improvement = iter_best_improvement

        if delta < -1e-9:
            accept = True
            improvement = True
        else:
            prob = np.exp(-delta / max(T, 1e-9))
            if random.random() < prob:
                accept = True

        if accept:
            current_routes = iter_best_routes
            current_cost   = iter_best_cost

            d_idx = iter_best_d_idx
            r_idx = iter_best_r_idx

            # best 갱신
            if current_cost < best_cost - 1e-9:
                best_cost = current_cost
                best_routes = copy.deepcopy(current_routes)
                destroy_scores[d_idx] += 4.0
                repair_scores[r_idx]  += 4.0
            elif improvement:
                destroy_scores[d_idx] += 2.0
                repair_scores[r_idx]  += 2.0
            else:
                destroy_scores[d_idx] += 0.5
                repair_scores[r_idx]  += 0.5

        # 4) 주기적으로 weight 업데이트
        if it % 30 == 0:
            for i in range(nD):
                destroy_weights[i] = (1 - reaction_factor) * destroy_weights[i] + reaction_factor * max(destroy_scores[i], 1e-6)
                destroy_scores[i] = 0.0
            for i in range(nR):
                repair_weights[i] = (1 - reaction_factor) * repair_weights[i] + reaction_factor * max(repair_scores[i], 1e-6)
                repair_scores[i] = 0.0

        if verbose and (it % 200 == 0 or it == max_iter):
            print(f"[Iter {it}] current={current_cost:.2f}, best={best_cost:.2f}, T={T:.4f}")

    return best_cost, best_routes


def solve_vrp_alns(demands, dist_matrix, vehicle_capacity,
                   max_iter=2000,
                   remove_fraction=0.3,   # 인터페이스 유지용 (내부에서는 min/max remove_frac 사용)
                   seed=0,
                   verbose=False):
    """
    기존 인터페이스 유지용 wrapper
    - 내부적으로는 heavy ALNS(alns_cvrp)를 호출
    """
    cost, routes = alns_cvrp(
        demands=demands,
        dist_matrix=dist_matrix,
        vehicle_capacity=vehicle_capacity,
        max_iter=max_iter,
        min_remove_frac=0.2,
        max_remove_frac=0.5,
        reaction_factor=0.2,
        start_temp=1.0,
        end_temp=0.01,
        inner_loops=5,
        seed=seed,
        verbose=verbose
    )
    return cost, routes

# ---------------------------------------------
# 6) MILP 모델 생성 (SCIP 버전)
# ---------------------------------------------
def build_milp_model(lam=None, min_cust=None, use_capacity=True):
    """
    lam      : 균형 제약 λ (None이면 미적용)
    min_cust : 최소 고객 수 (None이면 미적용)
    use_capacity : True면 DC CAPACITY 제약 적용
    """
    model = Model("FacilityLocation_SCIP")

    # 변수
    y = {j: model.addVar(vtype="B", name=f"OpenDC_{j}") for j in range(D)}
    x = {i: {j: model.addVar(vtype="B", name=f"Assign_{i}_{j}") for j in range(D)} for i in range(C)}

    # 거리 비용
    dist_cost = np.zeros((C, D))
    for i in range(C):
        for j in range(D):
            dist_cost[i, j] = euclid(cust_coords[i], dc_coords[j])

    # 목적함수: 개설비 + 배정 거리
    obj_expr = quicksum(y[j] * open_cost_j[j] for j in range(D)) + \
               quicksum(x[i][j] * dist_cost[i, j] for i in range(C) for j in range(D))
    model.setObjective(obj_expr, "minimize")

    # (공통) 각 고객은 정확히 하나의 DC에 배정
    for i in range(C):
        model.addCons(quicksum(x[i][j] for j in range(D)) == 1, name=f"AssignOne_{i}")

    # (공통) DC가 열려야 배정 가능 (x[i][j] <= y[j])
    for i in range(C):
        for j in range(D):
            model.addCons(x[i][j] <= y[j], name=f"OpenLink_{i}_{j}")

    # (선택) 제약 1: 균형 제약 (λ)
    if lam is not None:
        max_load = lam * total_demand
        for j in range(D):
            model.addCons(
                quicksum(x[i][j] * demand[i] for i in range(C)) <= max_load,
                name=f"BalanceLam_{j}"
            )

    # (선택) 제약 2: 최소 고객 수 제약
    if min_cust is not None:
        for j in range(D):
            model.addCons(
                quicksum(x[i][j] for i in range(C)) >= min_cust * y[j],
                name=f"MinCust_{j}"
            )

    # (선택) DC CAPACITY 제약
    if use_capacity:
        for j in range(D):
            model.addCons(
                quicksum(x[i][j] * demand[i] for i in range(C)) <= dc_capacity_j[j],
                name=f"DCCapacity_{j}"
            )

    return model, x, y

# ---------------------------------------------
# 7) MILP + ALNS VRP 통합 실행 (SCIP + HEAVY ALNS)
# ---------------------------------------------
def solve_milp_and_vrp_alns(case_name, lam=None, min_cust=None,
                            use_capacity=True,
                            alns_iter=500,
                            remove_fraction=0.2,   # wrapper용 파라미터 (실제 ALNS 안에서는 고정된 범위 사용)
                            scip_verbosity=False,
                            do_plot=False):
    print("\n============================")
    print(f"[{case_name}] MILP + ALNS VRP 풀이 시작 (SCIP)")
    print(f"  λ = {lam}, MIN_CUST = {min_cust}, CAPACITY_CONSTR = {use_capacity}")
    print("============================")

    model, x, y = build_milp_model(lam=lam, min_cust=min_cust, use_capacity=use_capacity)

    if not scip_verbosity:
        model.setIntParam("display/verblevel", 0)

    model.optimize()
    status = model.getStatus()
    print("MILP Status:", status)

    if status not in ["optimal", "bestsollimit", "timelimit"]:
        print(" → 최적해를 찾지 못했거나 infeasible 입니다.")
        return None

    opened_centers = []
    assignment     = {}

    for j in range(D):
        if model.getVal(y[j]) > 0.5:
            opened_centers.append(j)

    for i in range(C):
        for j in range(D):
            if model.getVal(x[i][j]) > 0.5:
                assignment[i] = j
                break

    if len(opened_centers) == 0:
        print(" → 어떤 DC도 열리지 않음 (infeasible 취급)")
        return None

    print("개설된 DC:", opened_centers)

    open_cost_total = sum(open_cost_j[j] for j in opened_centers)

    total_vrp_cost = 0.0
    routes_detail  = {}

    for dc_id in opened_centers:
        cust_list = [i for i in range(C) if assignment[i] == dc_id]
        if not cust_list:
            continue

        # 0: depot, 1~k: 고객
        locs = []
        dc_row = dc.loc[dc_id]
        locs.append((dc_row["X"], dc_row["Y"]))
        for cid in cust_list:
            crow = customer.loc[cid]
            locs.append((crow["X"], crow["Y"]))

        n = len(locs)
        dist_matrix = [[euclid(locs[i], locs[j]) for j in range(n)] for i in range(n)]
        demands_local = [0] + [int(demand[cid]) for cid in cust_list]

        vrp_dist, routes = solve_vrp_alns(
            demands=demands_local,
            dist_matrix=dist_matrix,
            vehicle_capacity=TRUCK_CAPACITY,
            max_iter=alns_iter,
            remove_fraction=remove_fraction,
            seed=dc_id,
            verbose=False
        )

        total_vrp_cost += vrp_dist
        routes_detail[dc_id] = {
            "routes": routes,
            "locs":  locs,
            "customers": cust_list
        }

        print(f"  DC {dc_id} | ALNS VRP 거리 = {vrp_dist:.2f}, routes 개수 = {len(routes)}")

    total_cost = open_cost_total + total_vrp_cost

    print(f"\n[{case_name}] 결과 요약")
    print("  개설된 DC:", opened_centers)
    print("  개설비용:", open_cost_total)
    print("  VRP 비용:", total_vrp_cost)
    print("  총비용:", total_cost)

    if do_plot:
        for dc_id in opened_centers:
            detail = routes_detail[dc_id]
            routes = detail["routes"]
            locs   = detail["locs"]

            plt.figure(figsize=(6,6))
            x_dc, y_dc = locs[0]
            plt.scatter(x_dc, y_dc, c="red", marker="X", s=180, label=f"DC {dc_id}")

            colors = ["tab:blue", "tab:orange", "tab:green", "tab:red",
                      "tab:purple", "tab:brown", "tab:pink", "tab:gray"]
            for r_idx, route in enumerate(routes):
                xs, ys = [], []
                for node in route:
                    x, y = locs[node]
                    xs.append(x); ys.append(y)
                    if node != 0:
                        plt.scatter(x, y, c=colors[r_idx % len(colors)], s=30)
                plt.plot(xs, ys, c=colors[r_idx % len(colors)], alpha=0.8)

            plt.title(f"{case_name} - DC {dc_id} Routes (ALNS, SCIP)")
            plt.xlabel("X"); plt.ylabel("Y")
            plt.grid(True); plt.legend()
            plt.show()

    result = {
        "case": case_name,
        "lambda": lam,
        "min_cust": min_cust,
        "opened": opened_centers,
        "open_cost": open_cost_total,
        "vrp_cost": total_vrp_cost,
        "total_cost": total_cost,
        "routes_detail": routes_detail,
        "assignment": assignment
    }
    return result

# ---------------------------------------------
# 8) λ / min_cust 후보 자동 생성
# ---------------------------------------------
def lambda_candidates():
    return [round(0.10 + 0.05 * k, 2) for k in range(0, 17)]

def min_cust_candidates():
    return list(range(5, C + 1, 5))

# ---------------------------------------------
# 9) 4가지 케이스 한 번에 실행 (SCIP + HEAVY ALNS)
# ---------------------------------------------
results_all = {}

# 공통 세팅
ALNS_ITER   = 2000
REMOVE_FRAC = 0.3   # 인터페이스용 (알고리즘 안에서는 min/max remove_frac 사용)

# A. 제약 없음
results_all["A_None"] = solve_milp_and_vrp_alns(
    case_name="A_NoConstraint_ALNS_SCIP",
    lam=None,
    min_cust=None,
    use_capacity=True,
    alns_iter=ALNS_ITER,
    remove_fraction=REMOVE_FRAC,
    do_plot=True
)

# B. 제약 1만 (λ)
print("\n=== B_LambdaOnly — λ grid search (SCIP + ALNS) ===")
best_B = None
for lam in lambda_candidates():
    res = solve_milp_and_vrp_alns(
        case_name=f"B_LambdaOnly_lam{lam}_ALNS_SCIP",
        lam=lam,
        min_cust=None,
        use_capacity=True,
        alns_iter=ALNS_ITER,
        remove_fraction=REMOVE_FRAC,
        do_plot=False
    )
    if res is None:
        print(f"  λ={lam:.2f} → infeasible")
        continue
    print(f"  λ={lam:.2f} → TOTAL={res['total_cost']:.2f}, opened={res['opened']}")
    if (best_B is None) or (res["total_cost"] < best_B["total_cost"]):
        best_B = res
results_all["B_LambdaOnly"] = best_B

# C. 제약 2만 (MIN_CUST)
print("\n=== C_MinCustOnly — min_cust grid search (SCIP + ALNS) ===")
best_C = None
for mc in min_cust_candidates():
    res = solve_milp_and_vrp_alns(
        case_name=f"C_MinCustOnly_mc{mc}_ALNS_SCIP",
        lam=None,
        min_cust=mc,
        use_capacity=True,
        alns_iter=ALNS_ITER,
        remove_fraction=REMOVE_FRAC,
        do_plot=False
    )
    if res is None:
        print(f"  min_cust={mc} → infeasible")
        continue
    print(f"  min_cust={mc} → TOTAL={res['total_cost']:.2f}, opened={res['opened']}")
    if (best_C is None) or (res["total_cost"] < best_C["total_cost"]):
        best_C = res
results_all["C_MinCustOnly"] = best_C

# D. 제약 1+2 동시 적용
print("\n=== D_Both — (λ, min_cust) grid search (SCIP + ALNS) ===")
best_D = None
for lam in lambda_candidates():
    for mc in min_cust_candidates():
        res = solve_milp_and_vrp_alns(
            case_name=f"D_Both_lam{lam}_mc{mc}_ALNS_SCIP",
            lam=lam,
            min_cust=mc,
            use_capacity=True,
            alns_iter=ALNS_ITER,
            remove_fraction=REMOVE_FRAC,
            do_plot=False
        )
        if res is None:
            print(f"  λ={lam:.2f}, min_cust={mc} → infeasible")
            continue
        print(f"  λ={lam:.2f}, min_cust={mc} → TOTAL={res['total_cost']:.2f}, opened={res['opened']}")
        if (best_D is None) or (res["total_cost"] < best_D["total_cost"]):
            best_D = res
results_all["D_Both"] = best_D

# ---------------------------------------------
# 10) 최종 비교 출력
# ---------------------------------------------
print("\n================ 최종 비교 (SCIP + HEAVY ALNS) ================")
for k, res in results_all.items():
    if res is None:
        print(k, "→ infeasible or failed")
    else:
        print(
            f"{k}: TOTAL={res['total_cost']:.2f}, opened={res['opened']}, "
            f"λ={res['lambda']}, min_cust={res['min_cust']}"
        )
print("=========================================================")
# Out:
# ============================
# [A_NoConstraint_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [A_NoConstraint_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
# === B_LambdaOnly — λ grid search (SCIP + ALNS) ===
#
# ============================
# [B_LambdaOnly_lam0.1_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10 → infeasible
#
# ============================
# [B_LambdaOnly_lam0.15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15 → infeasible
#
# ============================
# [B_LambdaOnly_lam0.2_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20 → infeasible
#
# ============================
# [B_LambdaOnly_lam0.25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3, 4]
#   DC 0 | ALNS VRP 거리 = 127.49, routes 개수 = 2
#   DC 1 | ALNS VRP 거리 = 137.81, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 168.98, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 127.57, routes 개수 = 2
#   DC 4 | ALNS VRP 거리 = 67.29, routes 개수 = 1
#
# [B_LambdaOnly_lam0.25_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3, 4]
#   개설비용: 200
#   VRP 비용: 629.1475103770321
#   총비용: 829.1475103770321
#   λ=0.25 → TOTAL=829.15, opened=[0, 1, 2, 3, 4]
#
# ============================
# [B_LambdaOnly_lam0.3_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | ALNS VRP 거리 = 140.40, routes 개수 = 2
#   DC 1 | ALNS VRP 거리 = 120.74, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 173.38, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.3_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 578.1056049729277
#   총비용: 738.1056049729277
#   λ=0.30 → TOTAL=738.11, opened=[0, 1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | ALNS VRP 거리 = 126.00, routes 개수 = 1
#   DC 1 | ALNS VRP 거리 = 120.74, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 174.28, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.35_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 564.6087748202511
#   총비용: 724.6087748202511
#   λ=0.35 → TOTAL=724.61, opened=[0, 1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.4_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 204.72, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 213.55, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.4_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 561.846657967492
#   총비용: 681.846657967492
#   λ=0.40 → TOTAL=681.85, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 186.01, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.87, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.45_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 566.4645084220037
#   총비용: 686.4645084220037
#   λ=0.45 → TOTAL=686.46, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.23, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 260.23, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 567.0381488360084
#   총비용: 687.0381488360084
#   λ=0.50 → TOTAL=687.04, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.55_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.55_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.55 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.6_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.6_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.60 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.65_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.65, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.65_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.65 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.7_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.7, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.7_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.70 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.75_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.75_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.75 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.8_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.8_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.80 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.85_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.85_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.85 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [B_LambdaOnly_lam0.9_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = None, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [B_LambdaOnly_lam0.9_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.90 → TOTAL=677.50, opened=[1, 2, 3]
#
# === C_MinCustOnly — min_cust grid search (SCIP + ALNS) ===
#
# ============================
# [C_MinCustOnly_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [C_MinCustOnly_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [C_MinCustOnly_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [C_MinCustOnly_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [C_MinCustOnly_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [C_MinCustOnly_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [C_MinCustOnly_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 326.63, routes 개수 = 4
#   DC 3 | ALNS VRP 거리 = 196.74, routes 개수 = 2
#
# [C_MinCustOnly_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 523.3672726448871
#   총비용: 603.3672726448871
#   min_cust=20 → TOTAL=603.37, opened=[2, 3]
#
# ============================
# [C_MinCustOnly_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 4]
#   DC 2 | ALNS VRP 거리 = 279.23, routes 개수 = 3
#   DC 4 | ALNS VRP 거리 = 239.77, routes 개수 = 3
#
# [C_MinCustOnly_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 519.0065832040832
#   총비용: 599.0065832040832
#   min_cust=25 → TOTAL=599.01, opened=[2, 4]
#
# ============================
# [C_MinCustOnly_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1]
#   DC 1 | ALNS VRP 거리 = 549.26, routes 개수 = 5
#
# [C_MinCustOnly_mc30_ALNS_SCIP] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 549.264701155798
#   총비용: 589.264701155798
#   min_cust=30 → TOTAL=589.26, opened=[1]
#
# ============================
# [C_MinCustOnly_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1]
#   DC 1 | ALNS VRP 거리 = 549.26, routes 개수 = 5
#
# [C_MinCustOnly_mc35_ALNS_SCIP] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 549.264701155798
#   총비용: 589.264701155798
#   min_cust=35 → TOTAL=589.26, opened=[1]
#
# ============================
# [C_MinCustOnly_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1]
#   DC 1 | ALNS VRP 거리 = 549.26, routes 개수 = 5
#
# [C_MinCustOnly_mc40_ALNS_SCIP] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 549.264701155798
#   총비용: 589.264701155798
#   min_cust=40 → TOTAL=589.26, opened=[1]
#
# ============================
# [C_MinCustOnly_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1]
#   DC 1 | ALNS VRP 거리 = 549.26, routes 개수 = 5
#
# [C_MinCustOnly_mc45_ALNS_SCIP] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 549.264701155798
#   총비용: 589.264701155798
#   min_cust=45 → TOTAL=589.26, opened=[1]
#
# ============================
# [C_MinCustOnly_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = None, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1]
#   DC 1 | ALNS VRP 거리 = 549.26, routes 개수 = 5
#
# [C_MinCustOnly_mc50_ALNS_SCIP] 결과 요약
#   개설된 DC: [1]
#   개설비용: 40
#   VRP 비용: 549.264701155798
#   총비용: 589.264701155798
#   min_cust=50 → TOTAL=589.26, opened=[1]
#
# === D_Both — (λ, min_cust) grid search (SCIP + ALNS) ===
#
# ============================
# [D_Both_lam0.1_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=5 → infeasible
#
# ============================
# [D_Both_lam0.1_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=10 → infeasible
#
# ============================
# [D_Both_lam0.1_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.1_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.1_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.1_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.1_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.1_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.1_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.1_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.1, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.10, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.15_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=5 → infeasible
#
# ============================
# [D_Both_lam0.15_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=10 → infeasible
#
# ============================
# [D_Both_lam0.15_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.15_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.15_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.15_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.15_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.15_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.15_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.15_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.15, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.15, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.2_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=5 → infeasible
#
# ============================
# [D_Both_lam0.2_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=10 → infeasible
#
# ============================
# [D_Both_lam0.2_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.2_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.2_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.2_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.2_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.2_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.2_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.2_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.2, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.20, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.25_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3, 4]
#   DC 0 | ALNS VRP 거리 = 127.49, routes 개수 = 2
#   DC 1 | ALNS VRP 거리 = 137.81, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 168.98, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 127.57, routes 개수 = 2
#   DC 4 | ALNS VRP 거리 = 67.29, routes 개수 = 1
#
# [D_Both_lam0.25_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3, 4]
#   개설비용: 200
#   VRP 비용: 629.1475103770321
#   총비용: 829.1475103770321
#   λ=0.25, min_cust=5 → TOTAL=829.15, opened=[0, 1, 2, 3, 4]
#
# ============================
# [D_Both_lam0.25_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3, 4]
#   DC 0 | ALNS VRP 거리 = 112.91, routes 개수 = 2
#   DC 1 | ALNS VRP 거리 = 103.65, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 143.21, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 95.90, routes 개수 = 1
#   DC 4 | ALNS VRP 거리 = 105.38, routes 개수 = 1
#
# [D_Both_lam0.25_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3, 4]
#   개설비용: 200
#   VRP 비용: 561.0580621210146
#   총비용: 761.0580621210146
#   λ=0.25, min_cust=10 → TOTAL=761.06, opened=[0, 1, 2, 3, 4]
#
# ============================
# [D_Both_lam0.25_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.25_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.25_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.25_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.25_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.25_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.25_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.25_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.25, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.25, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.3_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | ALNS VRP 거리 = 140.40, routes 개수 = 2
#   DC 1 | ALNS VRP 거리 = 120.74, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 173.38, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.3_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 578.1056049729277
#   총비용: 738.1056049729277
#   λ=0.30, min_cust=5 → TOTAL=738.11, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.3_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | ALNS VRP 거리 = 140.40, routes 개수 = 2
#   DC 1 | ALNS VRP 거리 = 120.74, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 173.38, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.3_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 578.1056049729277
#   총비용: 738.1056049729277
#   λ=0.30, min_cust=10 → TOTAL=738.11, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.3_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=15 → infeasible
#
# ============================
# [D_Both_lam0.3_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.3_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.3_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.3_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.3_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.3_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.3_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.3, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.30, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.35_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | ALNS VRP 거리 = 126.00, routes 개수 = 1
#   DC 1 | ALNS VRP 거리 = 120.74, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 174.28, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.35_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 564.6087748202511
#   총비용: 724.6087748202511
#   λ=0.35, min_cust=5 → TOTAL=724.61, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.35_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 1, 2, 3]
#   DC 0 | ALNS VRP 거리 = 126.00, routes 개수 = 1
#   DC 1 | ALNS VRP 거리 = 120.74, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 174.28, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.35_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 1, 2, 3]
#   개설비용: 160
#   VRP 비용: 564.6087748202511
#   총비용: 724.6087748202511
#   λ=0.35, min_cust=10 → TOTAL=724.61, opened=[0, 1, 2, 3]
#
# ============================
# [D_Both_lam0.35_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [0, 2, 3]
#   DC 0 | ALNS VRP 거리 = 185.73, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 216.49, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 178.22, routes 개수 = 2
#
# [D_Both_lam0.35_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [0, 2, 3]
#   개설비용: 120
#   VRP 비용: 580.4335692430735
#   총비용: 700.4335692430735
#   λ=0.35, min_cust=15 → TOTAL=700.43, opened=[0, 2, 3]
#
# ============================
# [D_Both_lam0.35_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.35_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.35_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.35_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.35_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.35_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.35_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.35, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.35, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.4_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 204.72, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 213.55, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.4_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 561.846657967492
#   총비용: 681.846657967492
#   λ=0.40, min_cust=5 → TOTAL=681.85, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.4_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 204.72, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 213.55, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.4_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 561.846657967492
#   총비용: 681.846657967492
#   λ=0.40, min_cust=10 → TOTAL=681.85, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.4_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 193.91, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 213.55, routes 개수 = 2
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.4_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 576.4978955971503
#   총비용: 696.4978955971503
#   λ=0.40, min_cust=15 → TOTAL=696.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.4_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.4_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.4_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.4_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.4_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.4_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.4_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.4, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.40, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.45_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 186.01, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.87, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.45_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 566.4645084220037
#   총비용: 686.4645084220037
#   λ=0.45, min_cust=5 → TOTAL=686.46, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.45_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 186.01, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.87, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.45_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 566.4645084220037
#   총비용: 686.4645084220037
#   λ=0.45, min_cust=10 → TOTAL=686.46, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.45_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 172.37, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.87, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.45_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 578.2768016948083
#   총비용: 698.2768016948083
#   λ=0.45, min_cust=15 → TOTAL=698.28, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.45_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.45_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.45_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.45_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.45_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.45_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.45_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.45, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.45, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.5_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.23, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 260.23, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.5_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 567.0381488360084
#   총비용: 687.0381488360084
#   λ=0.50, min_cust=5 → TOTAL=687.04, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.5_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.23, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 260.23, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.5_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 567.0381488360084
#   총비용: 687.0381488360084
#   λ=0.50, min_cust=10 → TOTAL=687.04, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.5_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.5_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.50, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.5_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=20 → infeasible
#
# ============================
# [D_Both_lam0.5_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=25 → infeasible
#
# ============================
# [D_Both_lam0.5_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.5_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.5_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.5_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.5_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.5, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.50, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.55_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.55_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.55, min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.55_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.55_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.55, min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.55_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.55_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.55, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.55_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 287.07, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 261.43, routes 개수 = 3
#
# [D_Both_lam0.55_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 548.5052521223513
#   총비용: 628.5052521223513
#   λ=0.55, min_cust=20 → TOTAL=628.51, opened=[2, 3]
#
# ============================
# [D_Both_lam0.55_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 275.84, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 243.78, routes 개수 = 3
#
# [D_Both_lam0.55_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 519.6184874679265
#   총비용: 599.6184874679265
#   λ=0.55, min_cust=25 → TOTAL=599.62, opened=[2, 3]
#
# ============================
# [D_Both_lam0.55_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.55, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.55_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.55, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.55_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.55, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.55_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.55, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.55_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.55, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.55, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.6_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.6_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.60, min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.6_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.6_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.60, min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.6_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.6_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.60, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.6_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 306.92, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 216.08, routes 개수 = 2
#
# [D_Both_lam0.6_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 522.9998029515241
#   총비용: 602.9998029515241
#   λ=0.60, min_cust=20 → TOTAL=603.00, opened=[2, 3]
#
# ============================
# [D_Both_lam0.6_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 4]
#   DC 2 | ALNS VRP 거리 = 279.23, routes 개수 = 3
#   DC 4 | ALNS VRP 거리 = 239.77, routes 개수 = 3
#
# [D_Both_lam0.6_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 519.0065832040832
#   총비용: 599.0065832040832
#   λ=0.60, min_cust=25 → TOTAL=599.01, opened=[2, 4]
#
# ============================
# [D_Both_lam0.6_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.60, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.6_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.6, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
# ...
#   λ = 0.7, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.70, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.7_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.7, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.70, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.75_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.75_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.75, min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.75_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.75_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.75, min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.75_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.75_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.75, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.75_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 326.63, routes 개수 = 4
#   DC 3 | ALNS VRP 거리 = 196.74, routes 개수 = 2
#
# [D_Both_lam0.75_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 523.3672726448871
#   총비용: 603.3672726448871
#   λ=0.75, min_cust=20 → TOTAL=603.37, opened=[2, 3]
#
# ============================
# [D_Both_lam0.75_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 4]
#   DC 2 | ALNS VRP 거리 = 279.23, routes 개수 = 3
#   DC 4 | ALNS VRP 거리 = 239.77, routes 개수 = 3
#
# [D_Both_lam0.75_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 519.0065832040832
#   총비용: 599.0065832040832
#   λ=0.75, min_cust=25 → TOTAL=599.01, opened=[2, 4]
#
# ============================
# [D_Both_lam0.75_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.75_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.75_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.75_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.75_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.75, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.75, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.8_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.8_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.80, min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.8_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.8_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.80, min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.8_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.8_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.80, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.8_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 326.63, routes 개수 = 4
#   DC 3 | ALNS VRP 거리 = 196.74, routes 개수 = 2
#
# [D_Both_lam0.8_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 523.3672726448871
#   총비용: 603.3672726448871
#   λ=0.80, min_cust=20 → TOTAL=603.37, opened=[2, 3]
#
# ============================
# [D_Both_lam0.8_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 4]
#   DC 2 | ALNS VRP 거리 = 279.23, routes 개수 = 3
#   DC 4 | ALNS VRP 거리 = 239.77, routes 개수 = 3
#
# [D_Both_lam0.8_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 519.0065832040832
#   총비용: 599.0065832040832
#   λ=0.80, min_cust=25 → TOTAL=599.01, opened=[2, 4]
#
# ============================
# [D_Both_lam0.8_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.8_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.8_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.8_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.8_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.8, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.80, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.85_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.85_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.85, min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.85_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.85_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.85, min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.85_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.85_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.85, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.85_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 326.63, routes 개수 = 4
#   DC 3 | ALNS VRP 거리 = 196.74, routes 개수 = 2
#
# [D_Both_lam0.85_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 523.3672726448871
#   총비용: 603.3672726448871
#   λ=0.85, min_cust=20 → TOTAL=603.37, opened=[2, 3]
#
# ============================
# [D_Both_lam0.85_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 4]
#   DC 2 | ALNS VRP 거리 = 279.23, routes 개수 = 3
#   DC 4 | ALNS VRP 거리 = 239.77, routes 개수 = 3
#
# [D_Both_lam0.85_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 519.0065832040832
#   총비용: 599.0065832040832
#   λ=0.85, min_cust=25 → TOTAL=599.01, opened=[2, 4]
#
# ============================
# [D_Both_lam0.85_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.85_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.85_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.85_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.85_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.85, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.85, min_cust=50 → infeasible
#
# ============================
# [D_Both_lam0.9_mc5_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 5, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.9_mc5_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.90, min_cust=5 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.9_mc10_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 10, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 134.39, routes 개수 = 1
#   DC 2 | ALNS VRP 거리 = 279.53, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 143.58, routes 개수 = 2
#
# [D_Both_lam0.9_mc10_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 557.5029586177579
#   총비용: 677.5029586177579
#   λ=0.90, min_cust=10 → TOTAL=677.50, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.9_mc15_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 15, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [1, 2, 3]
#   DC 1 | ALNS VRP 거리 = 163.70, routes 개수 = 2
#   DC 2 | ALNS VRP 거리 = 236.80, routes 개수 = 3
#   DC 3 | ALNS VRP 거리 = 169.04, routes 개수 = 2
#
# [D_Both_lam0.9_mc15_ALNS_SCIP] 결과 요약
#   개설된 DC: [1, 2, 3]
#   개설비용: 120
#   VRP 비용: 569.5330099039857
#   총비용: 689.5330099039857
#   λ=0.90, min_cust=15 → TOTAL=689.53, opened=[1, 2, 3]
#
# ============================
# [D_Both_lam0.9_mc20_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 20, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 3]
#   DC 2 | ALNS VRP 거리 = 326.63, routes 개수 = 4
#   DC 3 | ALNS VRP 거리 = 196.74, routes 개수 = 2
#
# [D_Both_lam0.9_mc20_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 3]
#   개설비용: 80
#   VRP 비용: 523.3672726448871
#   총비용: 603.3672726448871
#   λ=0.90, min_cust=20 → TOTAL=603.37, opened=[2, 3]
#
# ============================
# [D_Both_lam0.9_mc25_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 25, CAPACITY_CONSTR = True
# ============================
# MILP Status: optimal
# 개설된 DC: [2, 4]
#   DC 2 | ALNS VRP 거리 = 279.23, routes 개수 = 3
#   DC 4 | ALNS VRP 거리 = 239.77, routes 개수 = 3
#
# [D_Both_lam0.9_mc25_ALNS_SCIP] 결과 요약
#   개설된 DC: [2, 4]
#   개설비용: 80
#   VRP 비용: 519.0065832040832
#   총비용: 599.0065832040832
#   λ=0.90, min_cust=25 → TOTAL=599.01, opened=[2, 4]
#
# ============================
# [D_Both_lam0.9_mc30_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 30, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=30 → infeasible
#
# ============================
# [D_Both_lam0.9_mc35_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 35, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=35 → infeasible
#
# ============================
# [D_Both_lam0.9_mc40_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 40, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=40 → infeasible
#
# ============================
# [D_Both_lam0.9_mc45_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 45, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=45 → infeasible
#
# ============================
# [D_Both_lam0.9_mc50_ALNS_SCIP] MILP + ALNS VRP 풀이 시작 (SCIP)
#   λ = 0.9, MIN_CUST = 50, CAPACITY_CONSTR = True
# ============================
# MILP Status: infeasible
#  → 최적해를 찾지 못했거나 infeasible 입니다.
#   λ=0.90, min_cust=50 → infeasible
#
# ================ 최종 비교 (SCIP + HEAVY ALNS) ================
# A_None: TOTAL=677.50, opened=[1, 2, 3], λ=None, min_cust=None
# B_LambdaOnly: TOTAL=677.50, opened=[1, 2, 3], λ=0.55, min_cust=None
# C_MinCustOnly: TOTAL=589.26, opened=[1], λ=None, min_cust=30
# D_Both: TOTAL=599.01, opened=[2, 4], λ=0.6, min_cust=25
# =========================================================

# %%
# ============================================================
# (수정 버전) SCIP + HEAVY ALNS 결과 시각화 코드 (한 셀 버전)
#   - DC별 route를 한 그림에 다 그림
#   - 트럭마다 전역적으로 색 다르게
#   - demand 숫자는 고객당 "한 번만" 표시
# ============================================================
import matplotlib.pyplot as plt

# 트럭(경로)별 색상 팔레트
ROUTE_COLORS = [
    "tab:blue", "tab:orange", "tab:green", "tab:red",
    "tab:purple", "tab:brown", "tab:pink", "tab:gray",
    "tab:olive", "tab:cyan"
]

def plot_case_all_dc_scipalns(result, title=""):
    """
    SCIP + ALNS 결과: 경로만 보는 기본 버전
    result: solve_milp_and_vrp_alns 가 반환한 딕셔너리
    """
    if result is None:
        print(f"[{title}] 결과가 없습니다 (infeasible or failed).")
        return

    routes_detail = result["routes_detail"]
    opened        = result["opened"]

    plt.figure(figsize=(7, 7))

    # 전체 고객 위치를 연한 점으로 표시
    plt.scatter(customer["X"], customer["Y"],
                c="lightgray", s=15, alpha=0.5, label="All Customers")

    # ★ 모든 DC를 통틀어 트럭(route) index를 전역적으로 증가시키기
    global_route_idx = 0

    for dc_id in opened:
        detail = routes_detail[dc_id]
        routes = detail["routes"]
        locs   = detail["locs"]   # 0: DC, 1~: 그 DC가 담당하는 고객

        # DC 표시
        x_dc, y_dc = locs[0]
        plt.scatter(x_dc, y_dc, c="red", marker="X", s=180, label=f"DC {dc_id}")

        # 각 트럭 route마다 색 다르게 (전역 인덱스 기준)
        for route in routes:
            color = ROUTE_COLORS[global_route_idx % len(ROUTE_COLORS)]
            xs, ys = [], []
            for node in route:
                x, y = locs[node]
                xs.append(x); ys.append(y)
                if node != 0:
                    plt.scatter(x, y, c=color, s=35)
            plt.plot(xs, ys, c=color, alpha=0.8)

            global_route_idx += 1

    plt.title(title)
    plt.xlabel("X"); plt.ylabel("Y")
    plt.grid(True)

    # 중복 legend 제거
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), fontsize=8)

    plt.show()


def plot_case_all_dc_with_demand_scipalns(result, title=""):
    """
    SCIP + ALNS 결과: 고객 옆에 demand 숫자까지 표시하는 버전
    → 각 고객(global index)당 라벨은 딱 한 번만 찍음
    """
    if result is None:
        print(f"[{title}] 결과가 없습니다 (infeasible or failed).")
        return

    routes_detail = result["routes_detail"]
    opened        = result["opened"]

    plt.figure(figsize=(7, 7))

    # 전체 고객 위치 (배경용)
    plt.scatter(customer["X"], customer["Y"],
                c="lightgray", s=15, alpha=0.4)

    # 이미 라벨 찍은 고객(global index)을 기록
    already_labeled = set()

    # ★ 전역 route index (DC 상관없이 계속 증가)
    global_route_idx = 0

    for dc_id in opened:
        detail   = routes_detail[dc_id]
        routes   = detail["routes"]
        locs     = detail["locs"]
        cust_ids = detail["customers"]  # global index 리스트

        # DC 표시
        x_dc, y_dc = locs[0]
        plt.scatter(x_dc, y_dc, c="red", marker="X", s=180, label=f"DC {dc_id}")

        for route in routes:
            color = ROUTE_COLORS[global_route_idx % len(ROUTE_COLORS)]
            xs, ys = [], []
            for pos, node in enumerate(route):
                x, y = locs[node]
                xs.append(x); ys.append(y)

                if node != 0:
                    plt.scatter(x, y, c=color, s=35)

                    # node==1 → customers[0], node==2 → customers[1] ...
                    global_index = cust_ids[node-1]
                    # 아직 라벨 안 찍은 고객만 표시
                    if global_index not in already_labeled:
                        d = int(customer.loc[global_index, "DEMAND"])

                        # 겹침 줄이려고 index/pos 기준으로 offset 조금씩 다르게
                        dx = 0.8 if (global_index % 2 == 0) else -1.0
                        dy = 0.8 if (global_index % 3 == 0) else -0.8

                        plt.text(
                            x + dx, y + dy, f"{d}",
                            fontsize=7, color="black",
                            ha="center", va="center",
                            bbox=dict(facecolor="white",
                                      edgecolor="none",
                                      alpha=0.6)
                        )
                        already_labeled.add(global_index)

            plt.plot(xs, ys, c=color, alpha=0.8)
            global_route_idx += 1

    plt.title(title)
    plt.xlabel("X"); plt.ylabel("Y")
    plt.grid(True)

    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys(), fontsize=8)

    plt.show()


# ============================================================
# 4개 케이스 각각 2장씩 시각화 호출 (기본 + demand 표시)
# ============================================================

# ---- Case 1 ----
plot_case_all_dc_scipalns(
    results_all["A_None"],
    title="Case 1 (A_None, SCIP+ALNS) — No Constraints"
)
plot_case_all_dc_with_demand_scipalns(
    results_all["A_None"],
    title="Case 1 (A_None, SCIP+ALNS) — Demand "
)

# ---- Case 2 ----
if results_all["B_LambdaOnly"] is not None:
    plot_case_all_dc_scipalns(
        results_all["B_LambdaOnly"],
        title=f"Case 2 (B_LambdaOnly, SCIP+ALNS) — λ Only (λ={results_all['B_LambdaOnly']['lambda']})"
    )
    plot_case_all_dc_with_demand_scipalns(
        results_all["B_LambdaOnly"],
        title=f"Case 2 (B_LambdaOnly, SCIP+ALNS) — Demand  (λ={results_all['B_LambdaOnly']['lambda']})"
    )

# ---- Case 3 ----
if results_all["C_MinCustOnly"] is not None:
    plot_case_all_dc_scipalns(
        results_all["C_MinCustOnly"],
        title=f"Case 3 (C_MinCustOnly, SCIP+ALNS) — MinCust Only (min_cust={results_all['C_MinCustOnly']['min_cust']})"
    )
    plot_case_all_dc_with_demand_scipalns(
        results_all["C_MinCustOnly"],
        title=f"Case 3 (C_MinCustOnly, SCIP+ALNS) — Demand  (min_cust={results_all['C_MinCustOnly']['min_cust']})"
    )

# ---- Case 4 ----
if results_all["D_Both"] is not None:
    plot_case_all_dc_scipalns(
        results_all["D_Both"],
        title=f"Case 4 (D_Both, SCIP+ALNS) — λ + MinCust (λ={results_all['D_Both']['lambda']}, min_cust={results_all['D_Both']['min_cust']})"
    )
    plot_case_all_dc_with_demand_scipalns(
        results_all["D_Both"],
        title=f"Case 4 (D_Both, SCIP+ALNS) — Demand  (λ={results_all['D_Both']['lambda']}, min_cust={results_all['D_Both']['min_cust']})"
    )
